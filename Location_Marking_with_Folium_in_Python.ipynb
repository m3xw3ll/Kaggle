# %% [markdown]
# <a href="https://www.kaggle.com/code/mexwell/location-marking-with-folium-in-python?scriptVersionId=184377686" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <p style="font-weight:bold; letter-spacing: 2px; color:#000000; font-size:300%; padding: 0px; text-align:center;"> 📍 Location Marking with Folium in Python </p>
#
# In this short notebook I will show you how to add markers in Folium. The data set I use includes the NCAA stadiums.

# %% [markdown]
# # Setup

# %%
# Import 
import pandas as pd
import folium

# %%
data = pd.read_csv('/kaggle/input/ncaa-stadiums/stadiums-geocoded.csv')

# %%
data.head()
# Out:
#             stadium             city state        team conference  capacity  \
# 0  Michigan Stadium        Ann Arbor    MI    Michigan    Big Ten    107601
# 1    Beaver Stadium  University Park    PA  Penn State    Big Ten    106572
# 2      Ohio Stadium         Columbus    OH  Ohio State    Big Ten    104944
# 3        Kyle Field  College Station    TX   Texas A&M        SEC    102733
# 4   Neyland Stadium        Knoxville    TN   Tennessee        SEC    102455
#
#    built expanded  div   latitude  longitude
# 0   1927     2015  fbs  42.265869 -83.748726
# 1   1960     2001  fbs  40.812153 -77.856202
# 2   1922     2014  fbs  40.001686 -83.019728
# 3   1927     2015  fbs  30.610098 -96.340729
# 4   1921     2010  fbs  35.954734 -83.925333

# %% [markdown]
# # Create the Map
#
# We start with creating a basic world map.

# %%
m = folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6243470912c3c1c4fd53e100fe310767 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6243470912c3c1c4fd53e100fe310767&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6243470912c3c1c4fd53e100fe310767 = L.map(
#                 &quot;map_6243470912c3c1c4fd53e100fe310767&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_431e1bc57830279a6bc910e8768bc04a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6243470912c3c1c4fd53e100fe310767);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Since we only work with data in the US, we can set an initial zoom to North America.

# %%
m = folium.Map(location=[40.0, -100.0], zoom_start=4)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b70e76351dbef948e664eb5f98575286 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b70e76351dbef948e664eb5f98575286&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b70e76351dbef948e664eb5f98575286 = L.map(
#                 &quot;map_b70e76351dbef948e664eb5f98575286&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b458949844c227e6ddb67a6724159a18 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b70e76351dbef948e664eb5f98575286);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We 'cutted' the map. So sometimes it is usefull to have a `Minimap`.
# Therefore we have to import `plugins`.

# %%
from folium import plugins

# %%
m = folium.Map(location=[40.0, -100.0], zoom_start=4)
minimap = plugins.MiniMap()
m.add_child(minimap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a2a472cf42326137ad7f11dcb196813 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a2a472cf42326137ad7f11dcb196813&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a2a472cf42326137ad7f11dcb196813 = L.map(
#                 &quot;map_1a2a472cf42326137ad7f11dcb196813&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50155d1c64718d3ecfebb71a50fab2d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a2a472cf42326137ad7f11dcb196813);
#
#
#             var tile_layer_aa277d87154682640c5c2b67f16bed13 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_f4cf2d45c8e3884a0cf0e0517f71c9b4 = new L.Control.MiniMap(
#                 tile_layer_aa277d87154682640c5c2b67f16bed13,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_1a2a472cf42326137ad7f11dcb196813.addControl(mini_map_f4cf2d45c8e3884a0cf0e0517f71c9b4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Add Markers
#
# It´s time to add some data to our map.

# %%
m = folium.Map(location=[40.0, -100.0], zoom_start=4)
for index, row in data.iterrows():
    marker = folium.Marker([row['latitude'], row['longitude']])
    marker.add_to(m)
minimap = plugins.MiniMap()
m.add_child(minimap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b002ee790e98d84a7e394a81e42a0275 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b002ee790e98d84a7e394a81e42a0275&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b002ee790e98d84a7e394a81e42a0275 = L.map(
#                 &quot;map_b002ee790e98d84a7e394a81e42a0275&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f651ff7e4a7c85a26d12a14df5d9656 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_9f32dfa57ea82bb6feef08b0638be322 = L.marker(
#                 [42.26586873251738, -83.7487256526947],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_8ababf09ed1e6711f89b5b666cab9d09 = L.marker(
#                 [40.81215273275043, -77.85620212554932],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_1410f9ed2086a4fd3f5dae34f1726951 = L.marker(
#                 [40.0016856893694, -83.01972806453705],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_18c33df8fcadcca1fbf9f4e79b187fd5 = L.marker(
#                 [30.61009757817476, -96.34072922859283],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_0d00e6d69cd8b82e2aa727ca894cdf08 = L.marker(
#                 [35.95473437262258, -83.92533302307129],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_8ea8a2bc051d8a804241a20da966e3ba = L.marker(
#                 [30.4120123982997, -91.183819770813],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_885b949dc8bb87e5adc9c8a7fcb6badb = L.marker(
#                 [33.2074899449518, -87.5503921508789],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_3522339d2e58cc6b0a49dc9d990b35d8 = L.marker(
#                 [30.28360340206824, -97.73233652114868],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_05b237712f5cabad5fc7f077e4d41011 = L.marker(
#                 [34.01400974062912, -118.28789591789246],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_ac4f6a000cf0a629316a56bb320da7a1 = L.marker(
#                 [33.949821489498824, -83.37344169616699],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_7ceb0b2aef2fa5cbcba7ff549b03d7c6 = L.marker(
#                 [34.16156958726264, -118.1676149368286],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_071cd3d77041dc1cbbc8bb71c3379031 = L.marker(
#                 [29.649868677972304, -82.34866619110107],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_d77913b027296cbfd8f31c5d7bd96432 = L.marker(
#                 [32.602361666817515, -85.48891067504883],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_38b777f44ba69cf0c39e021d64226de0 = L.marker(
#                 [40.82048352329494, -96.70571565628052],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_1031ef49e8454a74a3048204042d51cd = L.marker(
#                 [30.437547584621285, -84.30453398103501],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_f2e882ec7c6b7a64e0161b17e9257191 = L.marker(
#                 [35.20589959488508, -97.44255065917967],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_a211234c48e54850893a64a9c95ef0ad = L.marker(
#                 [34.67874665741346, -82.84317970275879],
#                 {}
#             ).addTo(map_b002ee790e98d84a7e394a81e42a0275);
#
#
#             var marker_0c4fa148e8e739ae83cfd824e9678536 = L.marker(
#                 [41.69842312158612, -86.23382449150085],

# %% [markdown]
# The dataframe holds some useful information. In the next step we will create a tooltip and display following columns:
# - `Stadium`
# - `City`
# - `Team`
# - `Capacity`
# - `Built date`
# - `Expanded date`
#
# The info is shown on hover, if you need to show the info by clicking on the marker then use `popup` instead.

# %%
m = folium.Map(location=[40.0, -100.0], zoom_start=4)
for index, row in data.iterrows():
    marker = folium.Marker([row['latitude'], row['longitude']], 
                   tooltip=f"""
                   <b>Stadium:</b> {row['stadium']} 
                   <br>
                   <b>City:</b> {row['city']}
                   <br>
                   <b>Team:</b> {row['team']}
                   <br>
                   <b>Capacity:</b> {row['capacity']}
                   <br>
                   <b>Built date:</b> {row['built']}
                   <br>
                   <b>Expanded date:</b> {row['expanded']}
                   <br>
                   """)
    marker.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fd1162a85d854d161c7115d4eb5da6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fd1162a85d854d161c7115d4eb5da6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fd1162a85d854d161c7115d4eb5da6a = L.map(
#                 &quot;map_2fd1162a85d854d161c7115d4eb5da6a&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a900ee99a1b4314ca95bc3aaf3a8c7fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2fd1162a85d854d161c7115d4eb5da6a);
#
#
#             var marker_be02a65d3ac4700d4a5297a72273c242 = L.marker(
#                 [42.26586873251738, -83.7487256526947],
#                 {}
#             ).addTo(map_2fd1162a85d854d161c7115d4eb5da6a);
#
#
#             marker_be02a65d3ac4700d4a5297a72273c242.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Michigan Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; Ann Arbor
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Michigan
#                    &lt;br&gt;
#                    &lt;b&gt;Capacity:&lt;/b&gt; 107601
#                    &lt;br&gt;
#                    &lt;b&gt;Built date:&lt;/b&gt; 1927
#                    &lt;br&gt;
#                    &lt;b&gt;Expanded date:&lt;/b&gt; 2015
#                    &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f38c65e38ec42bb6a185290f8947648c = L.marker(
#                 [40.81215273275043, -77.85620212554932],
#                 {}
#             ).addTo(map_2fd1162a85d854d161c7115d4eb5da6a);
#
#
#             marker_f38c65e38ec42bb6a185290f8947648c.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Beaver Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; University Park
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Penn State
#                    &lt;br&gt;
#                    &lt;b&gt;Capacity:&lt;/b&gt; 106572
#                    &lt;br&gt;
#                    &lt;b&gt;Built date:&lt;/b&gt; 1960
#                    &lt;br&gt;
#                    &lt;b&gt;Expanded date:&lt;/b&gt; 2001
#                    &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9a0f600e1afbc7e6b67e9be8f6d5a81 = L.marker(
#                 [40.0016856893694, -83.01972806453705],
#                 {}
#             ).addTo(map_2fd1162a85d854d161c7115d4eb5da6a);
#
#
#             marker_e9a0f600e1afbc7e6b67e9be8f6d5a81.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Ohio Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; Columbus
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Ohio State
#                    &lt;br&gt;
#                    &lt;b&gt;Capacity:&lt;/b&gt; 104944
#                    &lt;br&gt;
#                    &lt;b&gt;Built date:&lt;/b&gt; 1922
#                    &lt;br&gt;
#                    &lt;b&gt;Expanded date:&lt;/b&gt; 2014
#                    &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_582ff874d1eefc96d0decf4d6c904a01 = L.marker(
#                 [30.61009757817476, -96.34072922859283],
#                 {}
#             ).addTo(map_2fd1162a85d854d161c7115d4eb5da6a);
#
#
#             marker_582ff874d1eefc96d0decf4d6c904a01.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Kyle Field
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; College Station
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Texas A&amp;M
#                    &lt;br&gt;
#                    &lt;b&gt;Capacity:&lt;/b&gt; 102733
#                    &lt;br&gt;
#                    &lt;b&gt;Built date:&lt;/b&gt; 1927
#                    &lt;br&gt;
#                    &lt;b&gt;Expanded date:&lt;/b&gt; 2015
#                    &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c8f93be4f5e74fa8a6602da15454f7ef = L.marker(
#                 [35.95473437262258, -83.92533302307129],
#                 {}
#             ).addTo(map_2fd1162a85d

# %% [markdown]
# We also have to opportunity to style our icons. See https://fontawesome.com/icons?d=gallery for full list if icons. Use with: `prefix='fa'`.
#
# Or the glyphicon icons of Bootstrap that are built-in and standard, thus without prefix needed. https://getbootstrap.com/docs/3.3/components/

# %%
m = folium.Map(location=[40.0, -100.0], zoom_start=4)
for index, row in data.iterrows():
    folium.Marker([row['latitude'], 
                   row['longitude']], 
                   tooltip=f"""
                   <b>Stadium:</b> {row['stadium']} 
                   <br>
                   <b>City:</b> {row['city']}
                   <br>
                   <b>Team:</b> {row['team']}
                   <br>
                   <b>Capacity:</b> {row['capacity']}
                   <br>
                   <b>Built date:</b> {row['built']}
                   <br>
                   <b>Expanded date:</b> {row['expanded']}
                   <br>
                   """,
                   icon=folium.Icon(color='black', 
                                    icon='football', 
                                    prefix='fa',
                                    )).add_to(m)

minimap = plugins.MiniMap()
m.add_child(minimap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82f715b59417c3fe07ef5730a4fd984e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82f715b59417c3fe07ef5730a4fd984e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82f715b59417c3fe07ef5730a4fd984e = L.map(
#                 &quot;map_82f715b59417c3fe07ef5730a4fd984e&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_133817db2fe43b8514ecad029704bd17 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_82f715b59417c3fe07ef5730a4fd984e);
#
#
#             var marker_ff2e6f3b38e7a9b29cc97801dcc08d45 = L.marker(
#                 [42.26586873251738, -83.7487256526947],
#                 {}
#             ).addTo(map_82f715b59417c3fe07ef5730a4fd984e);
#
#
#             var icon_8816371afdea5f9d2c8c65c19bd8725b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ff2e6f3b38e7a9b29cc97801dcc08d45.setIcon(icon_8816371afdea5f9d2c8c65c19bd8725b);
#
#
#             marker_ff2e6f3b38e7a9b29cc97801dcc08d45.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Michigan Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; Ann Arbor
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Michigan
#                    &lt;br&gt;
#                    &lt;b&gt;Capacity:&lt;/b&gt; 107601
#                    &lt;br&gt;
#                    &lt;b&gt;Built date:&lt;/b&gt; 1927
#                    &lt;br&gt;
#                    &lt;b&gt;Expanded date:&lt;/b&gt; 2015
#                    &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8e4f7694eb9cfc4a7664c5559f1c7820 = L.marker(
#                 [40.81215273275043, -77.85620212554932],
#                 {}
#             ).addTo(map_82f715b59417c3fe07ef5730a4fd984e);
#
#
#             var icon_bc6dd7c651ec0dc4e6e50bcd7249f98f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8e4f7694eb9cfc4a7664c5559f1c7820.setIcon(icon_bc6dd7c651ec0dc4e6e50bcd7249f98f);
#
#
#             marker_8e4f7694eb9cfc4a7664c5559f1c7820.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Beaver Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; University Park
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Penn State
#                    &lt;br&gt;
#                    &lt;b&gt;Capacity:&lt;/b&gt; 106572
#                    &lt;br&gt;
#                    &lt;b&gt;Built date:&lt;/b&gt; 1960
#                    &lt;br&gt;
#                    &lt;b&gt;Expanded date:&lt;/b&gt; 2001
#                    &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0026e5c0c59443c47dcb733bacfea3e2 = L.marker(
#                 [40.0016856893694, -83.01972806453705],
#                 {}
#             ).addTo(map_82f715b59417c3fe07ef5730a4fd984e);
#
#
#             var icon_8bdc8ba02bd7a716fc6906d64dafa730 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0026e5c0c59443c47dcb733bacfea3e2.setIcon(icon_8bdc8ba02bd7a716fc6906d64dafa730);
#
#
#             marker_0026e5c0c59443c47dcb733bacfea3e2.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Ohio Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; Columbus
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&g

# %% [markdown]
# The column`div` specifies the division and contains either **fbs** or **fcs**.<br>
# The [NCAA Division I Football Bowl Subdivision (FBS)](https://en.wikipedia.org/wiki/NCAA_Division_I_Football_Bowl_Subdivision#Overview), formerly known as Division I-A, is the highest level of college football in the United States.<br>
# The [NCAA Division I Football Championship Subdivision (FCS)](https://en.wikipedia.org/wiki/NCAA_Division_I_Football_Championship_Subdivision), formerly known as Division I-AA, is the second-highest level of college football in the United States.<br><br>
# At the moment we do not know if the home team of this stadium plays in FBS or FCS. We can do a highlighting based on the league.

# %%
lookup = {'fbs': 'red', 'fcs': 'blue'} # We create a lookup dict, red stands for fbs and blue stands for fcs
m = folium.Map(location=[40.0, -100.0], zoom_start=4)
for index, row in data.iterrows():
    folium.Marker([row['latitude'], 
                   row['longitude']], 
                   tooltip=f"""
                   <b>Stadium:</b> {row['stadium']} 
                   <br>
                   <b>City:</b> {row['city']}
                   <br>
                   <b>Team:</b> {row['team']}
                   <br>
                   <b>Capacity:</b> {row['capacity']}
                   <br>
                   <b>Built date:</b> {row['built']}
                   <br>
                   <b>Expanded date:</b> {row['expanded']}
                   <br>
                   """,
                   icon=folium.Icon(color=lookup[row['div']], # here we individually style the background based of the corrent column value of div
                                    icon='football', 
                                    prefix='fa',
                                    )).add_to(m)

minimap = plugins.MiniMap()
m.add_child(minimap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee98a9a6fb4dac92684b41b1836a6c89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee98a9a6fb4dac92684b41b1836a6c89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee98a9a6fb4dac92684b41b1836a6c89 = L.map(
#                 &quot;map_ee98a9a6fb4dac92684b41b1836a6c89&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0f12236b592d787492838fbafd2501a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ee98a9a6fb4dac92684b41b1836a6c89);
#
#
#             var marker_e06d4eaa8655da164e8eb2f828812450 = L.marker(
#                 [42.26586873251738, -83.7487256526947],
#                 {}
#             ).addTo(map_ee98a9a6fb4dac92684b41b1836a6c89);
#
#
#             var icon_e8802a2c1ab5c79b2b0abacec246bf86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e06d4eaa8655da164e8eb2f828812450.setIcon(icon_e8802a2c1ab5c79b2b0abacec246bf86);
#
#
#             marker_e06d4eaa8655da164e8eb2f828812450.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Michigan Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; Ann Arbor
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Michigan
#                    &lt;br&gt;
#                    &lt;b&gt;Capacity:&lt;/b&gt; 107601
#                    &lt;br&gt;
#                    &lt;b&gt;Built date:&lt;/b&gt; 1927
#                    &lt;br&gt;
#                    &lt;b&gt;Expanded date:&lt;/b&gt; 2015
#                    &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_28d940863b054ae17c2bf498191f9059 = L.marker(
#                 [40.81215273275043, -77.85620212554932],
#                 {}
#             ).addTo(map_ee98a9a6fb4dac92684b41b1836a6c89);
#
#
#             var icon_cece1022dc76b51f0788f00a81cafc00 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_28d940863b054ae17c2bf498191f9059.setIcon(icon_cece1022dc76b51f0788f00a81cafc00);
#
#
#             marker_28d940863b054ae17c2bf498191f9059.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Beaver Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; University Park
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Penn State
#                    &lt;br&gt;
#                    &lt;b&gt;Capacity:&lt;/b&gt; 106572
#                    &lt;br&gt;
#                    &lt;b&gt;Built date:&lt;/b&gt; 1960
#                    &lt;br&gt;
#                    &lt;b&gt;Expanded date:&lt;/b&gt; 2001
#                    &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_213d897c71e8c5fc14ce864e29820532 = L.marker(
#                 [40.0016856893694, -83.01972806453705],
#                 {}
#             ).addTo(map_ee98a9a6fb4dac92684b41b1836a6c89);
#
#
#             var icon_c711b17532a306ea9100fd4d3c945b9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_213d897c71e8c5fc14ce864e29820532.setIcon(icon_c711b17532a306ea9100fd4d3c945b9a);
#
#
#             marker_213d897c71e8c5fc14ce864e29820532.bindTooltip(
#                 `&lt;div&gt;
#
#                    &lt;b&gt;Stadium:&lt;/b&gt; Ohio Stadium
#                    &lt;br&gt;
#                    &lt;b&gt;City:&lt;/b&gt; Columbus
#                    &lt;br&gt;
#                    &lt;b&gt;Team:&lt;/b&gt; Ohi

# %% [markdown]
# # Working with FeatureGroups
#
# The visual difference of the markers is not yet perfect. With Folium you have the possibility to create groups or layers. The individual layers can be activated or deactivated with a selection.

# %%
lookup = {'fbs': 'red', 'fcs': 'blue'}  # We create a lookup dict, red stands for fbs and blue stands for fcs
m = folium.Map(location=[40.0, -100.0], zoom_start=4)

# Create FeatureGroups for fbs and fcs
fbs_group = folium.FeatureGroup(name='FBS Stadiums')
fcs_group = folium.FeatureGroup(name='FCS Stadiums')

for index, row in data.iterrows():
    marker = folium.Marker([row['latitude'], row['longitude']],
                           tooltip=f"""
                           <b>Stadium:</b> {row['stadium']}
                           <br>
                           <b>City:</b> {row['city']}
                           <br>
                           <b>Team:</b> {row['team']}
                           <br>
                           <b>Capacity:</b> {row['capacity']}
                           <br>
                           <b>Built date:</b> {row['built']}
                           <br>
                           <b>Expanded date:</b> {row['expanded']}
                           <br>
                           """,
                           icon=folium.Icon(color=lookup[row['div']],
                                            icon='football',
                                            prefix='fa',
                                            ))
    
    # Add the marker to the appropriate FeatureGroup based on the 'div' value
    if row['div'] == 'fbs':
        marker.add_to(fbs_group)
    elif row['div'] == 'fcs':
        marker.add_to(fcs_group)


fbs_group.add_to(m)
fcs_group.add_to(m)
folium.LayerControl().add_to(m)
minimap = plugins.MiniMap()
m.add_child(minimap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c20f8d2e199c2c2c1d75b951db050758 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c20f8d2e199c2c2c1d75b951db050758&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c20f8d2e199c2c2c1d75b951db050758 = L.map(
#                 &quot;map_c20f8d2e199c2c2c1d75b951db050758&quot;,
#                 {
#                     center: [40.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaa859b1e123b5c6d8fb0233860fc5cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c20f8d2e199c2c2c1d75b951db050758);
#
#
#             var feature_group_9966666e48b7b3ac0b3b2d987bf5b960 = L.featureGroup(
#                 {}
#             ).addTo(map_c20f8d2e199c2c2c1d75b951db050758);
#
#
#             var marker_366f62534e906c785647578ac12fb2d1 = L.marker(
#                 [42.26586873251738, -83.7487256526947],
#                 {}
#             ).addTo(feature_group_9966666e48b7b3ac0b3b2d987bf5b960);
#
#
#             var icon_3b143ccf2445610369387b5909963d14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_366f62534e906c785647578ac12fb2d1.setIcon(icon_3b143ccf2445610369387b5909963d14);
#
#
#             marker_366f62534e906c785647578ac12fb2d1.bindTooltip(
#                 `&lt;div&gt;
#
#                            &lt;b&gt;Stadium:&lt;/b&gt; Michigan Stadium
#                            &lt;br&gt;
#                            &lt;b&gt;City:&lt;/b&gt; Ann Arbor
#                            &lt;br&gt;
#                            &lt;b&gt;Team:&lt;/b&gt; Michigan
#                            &lt;br&gt;
#                            &lt;b&gt;Capacity:&lt;/b&gt; 107601
#                            &lt;br&gt;
#                            &lt;b&gt;Built date:&lt;/b&gt; 1927
#                            &lt;br&gt;
#                            &lt;b&gt;Expanded date:&lt;/b&gt; 2015
#                            &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bb87f321cdf3b201cc1d2c8dab0a88c9 = L.marker(
#                 [40.81215273275043, -77.85620212554932],
#                 {}
#             ).addTo(feature_group_9966666e48b7b3ac0b3b2d987bf5b960);
#
#
#             var icon_18a3072ec348a9c227489ef0742d87da = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bb87f321cdf3b201cc1d2c8dab0a88c9.setIcon(icon_18a3072ec348a9c227489ef0742d87da);
#
#
#             marker_bb87f321cdf3b201cc1d2c8dab0a88c9.bindTooltip(
#                 `&lt;div&gt;
#
#                            &lt;b&gt;Stadium:&lt;/b&gt; Beaver Stadium
#                            &lt;br&gt;
#                            &lt;b&gt;City:&lt;/b&gt; University Park
#                            &lt;br&gt;
#                            &lt;b&gt;Team:&lt;/b&gt; Penn State
#                            &lt;br&gt;
#                            &lt;b&gt;Capacity:&lt;/b&gt; 106572
#                            &lt;br&gt;
#                            &lt;b&gt;Built date:&lt;/b&gt; 1960
#                            &lt;br&gt;
#                            &lt;b&gt;Expanded date:&lt;/b&gt; 2001
#                            &lt;br&gt;
#
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_91a959a04001fd395c19b42ccbcc1da2 = L.marker(
#                 [40.0016856893694, -83.01972806453705],
#                 {}
#             ).addTo(feature_group_9966666e48b7b3ac0b3b2d987bf5b960);
#
#
#             var icon_593bf772fdea4e6a8ffe3e30eb97f155 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;football&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_91a959a04001fd395c19b42
